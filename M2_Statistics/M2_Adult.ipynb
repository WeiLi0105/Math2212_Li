# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
file = open('adult.data', 'r')
def  chr_int(a):
    if a.isdigit(): return  int(a)
    else: return 0
    
data = []
for  line in file:
    data1 = line.split(', ')
    if len(data1) == 15:
        data.append ([
            chr_int(data1 [0]), data1[1],
            chr_int(data1 [2]), data1[3],
            chr_int(data1 [4]), data1[5],
            data1 [6], data1[7],  data1[8],
            data1 [9],  chr_int(data1 [10]),
            chr_int(data1 [11]),
            chr_int(data1 [12]),
            data1 [13],  data1 [14].strip()
        ])
data
# Out:
# [[39,
#   'State-gov',
#   77516,
#   'Bachelors',
#   13,
#   'Never-married',
#   'Adm-clerical',
#   'Not-in-family',
#   'White',
#   'Male',
#   2174,
#   0,
#   40,
#   'United-States',
#   '<=50K'],
#  [50,
#   'Self-emp-not-inc',
#   83311,
#   'Bachelors',
#   13,
#   'Married-civ-spouse',
#   'Exec-managerial',
#   'Husband',
#   'White',
#   'Male',
#   0,
#   0,
#   13,
#   'United-States',
#   '<=50K'],
#  [38,
#   'Private',
#   215646,
#   'HS-grad',
#   9,
#   'Divorced',
#   'Handlers-cleaners',
#   'Not-in-family',
#   'White',
#   'Male',
#   0,
#   0,
#   40,
#   'United-States',
#   '<=50K'],
#  [53,
#   'Private',
#   234721,
#   '11th',
#   7,
#   'Married-civ-spouse',
#   'Handlers-cleaners',
#   'Husband',
#   'Black',
#   'Male',
#   0,
#   0,
#   40,
#   'United-States',
#   '<=50K'],
#  [28,
#   'Private',
#   338409,
#   'Bachelors',
#   13,
#   'Married-civ-spouse',
#   'Prof-specialty',
#   'Wife',
#   'Black',
#   'Female',
#   0,
#   0,
#   40,
# ...

# %% [markdown]
# # Worksheet 2
#
# What is the ’r’ in the first line?
#
# 'r':read only file
#
# What does the function chr_int do?
#
# What is thesecond part of the code doing?  Try compiling with the ’data1 == line.split(’, ’)’ line including and notincluding the space after the comma.  What’s the difference?

# %% [markdown]
# # Worksheet 3
#
# what might be the best data structure to place this data in?

# %%
adult = pd.DataFrame(
    data, 
    columns=[
        'age','type_employer','final_weight',
        'education', 'education_num', 'martial',
        'occupation','relationship','race',
        'sex', 'capital_gain', 'capital_loss',
        'hr_per_week','country', 'income'
    ]
)

# %% [markdown]
# # Worksheet 4
#
# How does Python associate a column name to its column?

# %% [markdown]
# # Worksheet 5
#
# Print out the first few lines of the adult dataframe.

# %%
adult.head()
# Out:
#    age     type_employer  final_weight  education  education_num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#               martial         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# 0          2174             0           40  United-States  <=50K
# ...

# %% [markdown]
# # Recall the guiding research question
#
# "Are men more likely than women to become high income earners(more than $ 50k/year) ?"(proportion)

# %% [markdown]
# # inspire the creatino of several sub-dataframe
#
# all men
#
# all woman
#
# high income men
#
# high income women
#
# low income men
#
# low income women

# %%
men = adult[adult['sex'] == 'Male']
women = adult[adult['sex'] == 'Female']

men_high_income = adult[(adult['sex'] == 'Male')& (adult['income'] == '>50K')]
women_high_income = adult[(adult['sex'] == 'Female')& (adult['income'] == '>50K')]
men_low_income = adult[(adult['sex'] == 'Male')& (adult['income'] == '<=50K')]
women_low_income = adult[(adult['sex'] == 'Female')& (adult['income'] == '<=50K')]

# %%
men
# Out:
#        age     type-employer  fnlwgt     education  education_num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 13      32           Private  205019    Assoc-acdm             12
# 14      40           Private  121772     Assoc-voc             11
# 15      34           Private  245487       7th-8th              4
# 16      25  Self-emp-not-inc  176756       HS-grad              9
# 17      32           Private  186824       HS-grad              9
# ...

# %%
women
# Out:
#        age     type-employer  fnlwgt     education  education_num  \
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 8       31           Private   45781       Masters             14
# 12      23           Private  122272     Bachelors             13
# 19      43  Self-emp-not-inc  292175       Masters             14
# 21      54           Private  302146       HS-grad              9
# 24      59           Private  109015       HS-grad              9
# 37      19           Private  544091       HS-grad              9
# 43      49           Private   94638       HS-grad              9
# 47      44           Private  128354       Masters             14
# 50      25           Private   32275  Some-college             10
# 51      18           Private  226956       HS-grad              9
# ...

# %%
men_high_income
# Out:
#        age     type-employer  fnlwgt     education  education_num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 53      50       Federal-gov  251585     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 63      42           Private  116632     Doctorate             16
# ...

# %% [markdown]
# # Bootstrap

# %%
def mean_bootstrap(sample_data,number_of_resamples):
    x=[0]*number_of_resamples #initializes array
    for i in range(number_of_resamples):
        resample = [sample_data[j]
            for j
            in np.random.randint(len(sample_data),size=len(sample_data))
            ]
        x[i] = np.mean(resample)
    return x

# %%
def median_bootstrap(sample_data1,sample_data2,number_of_resamples):
    x=[0]*number_of_resamples #initializes an array
    for i in range(number_of_resamples):
        resample1 = [sample_data1[j]
            for j
            in np.random.randint(len(sample_data1),size=len(sample_data1))
            ]
        resample2 = [sample_data2[k]
            for k
            in np.random.randint(len(sample_data2),size=len(sample_data2))
            ]
        x[i] = np.median(resample1)-np.median(resample2)
    return x

# %%
m = mean_bootstrap(adult["age"], 100)
plt.hist(m)
plt.show()

# %%
print " The mean age of our empirical distribution is", np.mean(m)
print "The standard error age of our empirical distribution is ", np.std(m)

print "The mean age of all adults is", np.mean(adult["age"])
# Out:
#  The mean age of our empirical distribution is 38.585578759866095
# The standard error age of our empirical distribution is  0.07019715826725903
# The mean age of all adults is 38.5816467553

# %% [markdown]
# # Creating a 95% confidence interval

# %%
ci = [np.percentile(m,2.5), np.percentile(m,97.5)]

ci
# Out:
# [38.45309419243881, 38.71443521390621]

# %% [markdown]
# # Module 2 --EDA Basics

# %%
adult.shape
# Out:
# (32561, 15)

# %% [markdown]
# 15 columns, these are alternatively called:
# * column
# * variable
# * feature
# * covariate

# %% [markdown]
# # Worksheet 2
#
# find size of those dataframe: men women

# %%
men.shape
# Out:
# (21790, 15)

# %%
women.shape
# Out:
# (10771, 15)

# %%
men_high_income.shape
# Out:
# (6662, 15)

# %%
women_high_income.shape
# Out:
# (1179, 15)

# %%
men_low_income.shape
# Out:
# (15128, 15)

# %%
women_low_income.shape
# Out:
# (9592, 15)

# %% [markdown]
# Some questions to think for EDA:
#
# * What are the features/ variables / columns in this dataset?
# * Are they numerical or categorical?
# * Does the data seem sensible? I s it relevant?
# * Does the data seen to be in right scale? 0.000031 meters should be 31 micrometers
# * Does it seem like there's a lot of missing data?
# * Do you know what all the variables are?

# %% [markdown]
# # Module 2 -- Removing Outliers
#
# Three ways to remove outliers:
#    1) domanin expertise
#
#    2) mean/ std method
#
#    3) median/interquartile range method
#
# remove outliers that are too far from the center of our dataset
#    1)What is the center of the data?
#
#    2)how do we measure distance in a dataset?
#
#    3)how far is too far?

# %% [markdown]
# ## The mean /standard deviation method

# %%
adult['age'].mean()
# Out:
# 38.58164675532078

# %% [markdown]
# ## Worksheet M2T4 Question 1

# %%
men['age'].mean()
# Out:
# 39.43354749885268

# %%
women['age'].mean()
# Out:
# 36.85823043357163

# %%
men_high_income['age'].mean()
# Out:
# 44.62578805163614

# %%
women_high_income['age'].mean()
# Out:
# 36.210800667222685

# %%
adult['age'].var()
# Out:
# 186.06140024879625

# %%
adult['age'].std()
# Out:
# 13.640432553581146

# %%
adult.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009E44198>,
# ...
#       dtype=object)

# %% [markdown]
# # Worksheet M2T4 Question 2

# %%
men['age'].var()
# Out:
# 178.77375174530096

# %%
men['age'].std()
# Out:
# 13.37063019252649

# %%
women['age'].var()
# Out:
# 196.3837063948037

# %%
women['age'].std()
# Out:
# 14.01369709943824

# %%
men_high_income['age'].var()
# Out:
# 109.94506674864817

# %%
men_high_income['age'].std()
# Out:
# 10.485469314658651

# %%
women_high_income['age'].var()
# Out:
# 109.41377041059503

# %%
women_high_income['age'].std()
# Out:
# 10.460103747601886

# %% [markdown]
# ## Worksheet M2T4 Question 4
#
# Make a histogram for the numerical variables in each of the sub-dataframes that we created: men, women, high income men, high income women, low income men, low income women

# %%
men.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001072DCC0>,
# ...
#       dtype=object)

# %%
women.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010EE9828>,
# ...
#       dtype=object)

# %%
men_high_income.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001136D208>,
# ...
#       dtype=object)

# %%
women_high_income.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011C25EB8>,
# ...
#       dtype=object)

# %%
men_low_income.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012414588>,
# ...
#       dtype=object)

# %%
women_low_income.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000126EC5C0>,
# ...
#       dtype=object)

# %%
#make a histogram for a single column

adult.hist(column='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009FFEB70>]],
#       dtype=object)

# %%
adult.hist(column=['age', 'education_num', 'final_weight'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E239198>,
# ...
#       dtype=object)

# %% [markdown]
# # Center and Distance -- Median and interquartile range

# %% [markdown]
# Median caputres the middle data point

# %%
#computing the mdeian

adult['age'].median()
# Out:
# 37.0

# %% [markdown]
# # Worksheet M2T4 Question 5
#
# Find the median ages of men, women, and high income men and women.

# %%
men['age'].median()
# Out:
# 38.0

# %%
women['age'].median()
# Out:
# 35.0

# %%
men_high_income['age'].median()
# Out:
# 44.0

# %%
women_high_income['age'].median()
# Out:
# 41.0

# %% [markdown]
# # QUANTILES
#
# A way to split up the dataset into equal sized pieces
#
# * percentile chop up data into 100 pieces
#
# * quartiles chop up data into 4 pieces
#
# * quintile chop up data into 5 pieces

# %% [markdown]
# # Worksheet 6
# What is another name for the 50th percentile?
#
# Median

# %% [markdown]
# Quantiles aren't always numbers in the dataset

# %%
# computing quantiles in python 

print adult['age'].quantile(0.1) #10th percentile
print adult['age'].quantile(0.25) #25th percentile
print adult['age'].quantile(0.5) #50th percentile
# Out:
# 22.0
# 28.0
# 37.0

# %% [markdown]
# ## Worksheet M2T4 Question 7
#
# Define a function using the def method that inputs a numerical variable and outputsits interquartile range.  Use that to find the interquartile ranges for the age of men, women, high income men, and high income women.

# %%
def IQR(num):
    iqr=num.quantile(0.75)-num.quantile(0.25)
    return iqr

print IQR(men['age'])
print IQR(women['age'])
print IQR(men_high_income['age'])
print IQR(women_high_income['age'])
# Out:
# 19.0
# 21.0
# 14.0
# 15.0

# %%
# boxplot

adult.boxplot ()

# %% [markdown]
# # Removing outliers

# %%
# create a copy of the  original  dataset  as a backup

adult_original_data = adult

# count the total number of oulier rows at each extreme

print len(adult[adult['age']<22])
print len(adult[adult['age']>72])

#count the total number of outlier rows at each extreme for high income earners

print len(adult[ (adult['income'] == '>50K') & (adult['age'] <22) ] )
print len(adult[ (adult['income'] == '>50K') & (adult['age'] >72) ] )
# Out:
# 3130
# 401
# 5
# 69

# %%
#create a new dataframe with outliers dropped

adult_expert_outlier_drop = adult.drop(
    adult.index[
        ( adult['age'] <22 ) | (adult['age'] >72)
    ]
)

adult_expert_outlier_drop.head()
# Out:
#    age     type_employer  final_weight  education  education_num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#               martial         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# 0          2174             0           40  United-States  <=50K
# ...

# %% [markdown]
# # Removing outliers using the median and interquartile range

# %%
# create syntactical sugar

age = adult['age']
income = adult['income']
age_mean = age.mean()
age_std=age.std()
print age_mean
print age_std

# count  total  number  of  outlier we have

print len(adult[ age > age_mean+2.5*age_std ])
print len(adult[ age < age_mean-2.5*age_std ])

# count the number of outliers we have from high income earner
print len(adult[(income == '>50K')&(age > age_mean+2.5*age_std) ])
print len(adult[(income == '>50K')&(age < age_mean-2.5*age_std) ])

#drop these outliers

adult_mean_outlier_drop = adult.drop(
    adult.index[
        (age > age_mean+2.5*age_std) | (age < age_mean-2.5*age_std)
    ]
)

print age_mean-2.5*age_std
print age_mean+2.5*age_std

adult_mean_outlier_drop.head()
# Out:
# 38.5816467553
# 13.6404325536
# 401
# 0
# 69
# 0
# 4.48056537137
# 72.6827281393
#    age     type_employer  final_weight  education  education_num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#               martial         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# ...

# %% [markdown]
# # Removing outliers using the median and interquartile range

# %%
# count  total  number  of  outlier  rows at each  extreme  for  high  income  earners

# create syntactical sugar

age = adult['age']
income = adult['income']
age_median = age.median()
age_iqr = age.quantile(0.75) - age.quantile(0.25)
print age_median
print age_iqr 

# count  total  number  of  outlier we have

print len(adult[ age > age_median+1.5*age_iqr ])
print len(adult[ age < age_median-1.5*age_iqr  ])

# count the number of outliers we have from high income earner
print len(adult[(income == '>50K')&(age > age_median+1.5*age_iqr) ])
print len(adult[(income == '>50K')&(age < age_median-1.5*age_iqr) ])

#drop these outliers

adult_median_outlier_drop = adult.drop(
    adult.index[
        (age >  age_median+1.5*age_iqr) | (age < age_median-1.5*age_iqr)
    ]
)

print age_median+1.5*age_iqr
print age_median-1.5*age_iqr

adult_median_outlier_drop.head()
# Out:
# 37.0
# 20.0
# 857
# 0
# 161
# 0
# 67.0
# 7.0
#    age     type_employer  final_weight  education  education_num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#               martial         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# ...

# %% [markdown]
# # Module 2 Topic 5 -eda

# %%
adult_eda = adult_expert_outlier_drop 
adult_eda.head()
# Out:
#    age     type_employer  final_weight  education  education_num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#               martial         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# 0          2174             0           40  United-States  <=50K
# ...

# %% [markdown]
# ## Measures of Centrality and Spread
#
# find mean or median for full numerical variables, standard deviation or IQR

# %% [markdown]
# # Worksheet M2T5 Question 1
#
# For the new adult dataframe, find the mean, standard deviation, median and IQR for men, women, high income men and high income women.  Also draw the histograms and boxplots.

# %%
men_eda= adult_eda[adult_eda['sex'] == 'Male']
women_eda= adult_eda[adult_eda['sex'] == 'Female']

# %%
men_high_income_eda= adult_eda[(adult_eda['sex'] == 'Male')& (adult_eda['income'] == '>50K')]
women_high_income_eda= adult_eda[(adult_eda['sex'] == 'Female')& (adult_eda['income'] == '>50K')]
men_low_income_eda= adult_eda[(adult_eda['sex'] == 'Male') & (adult_eda['income'] == '<=50K')]
women_low_income_eda = adult_eda[(adult_eda['sex'] == 'Female')& (adult_eda['income'] == '<=50K')]

# %%
print men_eda.mean()

print men_eda.median()

print men_eda.std()

print men_eda.quantile(0.75)-men_eda.quantile(0.25)
# Out:
# age                  40.553517
# final_weight     191100.812880
# education_num        10.240461
# capital_gain       1422.156252
# capital_loss        104.940274
# hr_per_week          43.490976
# dtype: float64
# age                  39.0
# final_weight     179488.0
# education_num        10.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          40.0
# dtype: float64
# age                  11.846848
# final_weight     106511.065510
# education_num         2.666072
# capital_gain       8629.237853
# capital_loss        439.451271
# hr_per_week          11.416660
# dtype: float64
# age                  18.0
# final_weight     121863.0
# education_num         4.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          10.0
# dtype: float64

# %%
print women_eda.mean()

print women_eda.median()

print women_eda.std()

print women_eda.quantile(0.75)-women_eda.quantile(0.25)
# Out:
# age                  39.165992
# final_weight     185303.377612
# education_num        10.222344
# capital_gain        634.547653
# capital_loss         62.845497
# hr_per_week          38.054382
# dtype: float64
# age                  38.0
# final_weight     175821.0
# education_num        10.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          40.0
# dtype: float64
# age                  12.263991
# final_weight     102307.295621
# education_num         2.440587
# capital_gain       5198.121351
# capital_loss        344.105784
# hr_per_week          11.037581
# dtype: float64
# age                  18.0
# final_weight     109975.5
# education_num         4.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week           5.0
# dtype: float64

# %%
print men_high_income_eda.mean()

print men_high_income_eda.median()

print men_high_income_eda.std()

print men_high_income_eda.quantile(0.75)-men_high_income_eda.quantile(0.25)
# Out:
# age                  44.325352
# final_weight     188984.954842
# education_num        11.581452
# capital_gain       3937.792847
# capital_loss        198.317169
# hr_per_week          46.470374
# dtype: float64
# age                  44.0
# final_weight     176814.0
# education_num        12.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          44.0
# dtype: float64
# age                  10.012303
# final_weight     103111.818258
# education_num         2.400615
# capital_gain      14595.390955
# capital_loss        597.615461
# hr_per_week          10.584365
# dtype: float64
# age                  14.0
# final_weight     113540.0
# education_num         4.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          10.0
# dtype: float64

# %%
print women_high_income_eda.mean()

print women_high_income_eda.median()

print women_high_income_eda.std()

print women_high_income_eda.quantile(0.75)-women_high_income_eda.quantile(0.25)
# Out:
# age                  41.932363
# final_weight     183906.411815
# education_num        11.790240
# capital_gain       4089.238014
# capital_loss        172.130993
# hr_per_week          40.514555
# dtype: float64
# age                  41.0
# final_weight     172640.0
# education_num        13.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week          40.0
# dtype: float64
# age                  9.989526
# final_weight     99421.734430
# education_num        2.238865
# capital_gain     13928.097631
# capital_loss       570.030334
# hr_per_week         11.180905
# dtype: float64
# age                  15.0
# final_weight     105384.5
# education_num         3.0
# capital_gain          0.0
# capital_loss          0.0
# hr_per_week           7.0
# dtype: float64

# %%
men_eda.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D288550>,
# ...
#       dtype=object)

# %%
men_eda.boxplot(column = 'age')

# %%
women_eda.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001201F470>,
# ...
#       dtype=object)

# %%
women_eda.boxplot(column = 'age')

# %%
men_high_income_eda.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000104EEF28>,
# ...
#       dtype=object)

# %%
men_high_income_eda.boxplot(column = 'age')

# %%
women_high_income_eda.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000014406D30>,
# ...
#       dtype=object)

# %%
women_high_income_eda.boxplot(column = 'age')

# %% [markdown]
# ##  Measure of Symmetry
#
# How symmetric is your data? so is your data symmetric about the mean or is it *skewed* to one direction?

# %% [markdown]
# 1) mean < nedian => skewed left
#
# 2) mean = median => no skew
#
# 3) mean > median => skewed right
#
#
# There is an equation for skewness
#
# $$  g_1 = \dfrac{1}{n-1}\dfrac{\sum_i (x_i -\bar{x})^3}{s^3}$$
#
# positive: right skewed; zero: no skewed; negative: left skewed

# %%
# compute skew of age

print adult_eda['age'].skew()

# mean and median age:

print adult_eda['age'].mean()

print adult_eda['age'].median()

# %% [markdown]
# # Worksheet M2T5 Question 2

# %%
#Compute the skew of the age of men, women, high income men, and high income women 

print men_eda['age'].skew()
print women_eda['age'].skew()
print men_high_income_eda['age'].skew()
print women_high_income_eda['age'].skew()
# Out:
# 0.43641534933720055
# 0.5512599490866336
# 0.26939920786882
# 0.403152886883592

# %%
women_eda['age'].hist()

# %%
## define a correlation matrix, gethers the correlation between all numerical variables

adult_corr_matrix = adult_eda.corr()

print adult_corr_matrix
# Out:
#                     age  final_weight  education_num  capital_gain  \
# age            1.000000     -0.073073      -0.039343      0.068705
# final_weight  -0.073073      1.000000      -0.039922      0.000340
# education_num -0.039343     -0.039922       1.000000      0.119634
# capital_gain   0.068705      0.000340       0.119634      1.000000
# capital_loss   0.048611     -0.009608       0.077492     -0.033809
# hr_per_week   -0.029636     -0.022346       0.106808      0.074542
#
#                capital_loss  hr_per_week
# age                0.048611    -0.029636
# final_weight      -0.009608    -0.022346
# education_num      0.077492     0.106808
# capital_gain      -0.033809     0.074542
# capital_loss       1.000000     0.050921
# hr_per_week        0.050921     1.000000

# %%
#import seaborn library

import seaborn as sns

#plot a correlation heay map

sns.heatmap(
    adult_corr_matrix,
    xticklabels = adult_corr_matrix.columns,
    yticklabels = adult_corr_matrix.columns,
    annot=True
)

# %%
sns.scatterplot(data=adult_eda, x='age',y='final_weight')

plt.show()

# %%
#customize the plot by colring the points by some group 
sns.scatterplot(data=adult_eda, x='age',y='final_weight',hue = "education_num")

plt.show()

# %%
#customize the plot by sizing the points by some group numerical variable

sns.scatterplot(data=adult_eda, x='age',y='final_weight',size = "education_num")

plt.show()

# %% [markdown]
# # Bar Charts for Categrical variables

# %%
#to draw a barchart, we need to count the number of times each value appears in a categorical varianle 



#worksheet 4

count_emp = adult.groupby(['type_employer']).size()

print count_emp
# Out:
# type_employer
# ?                    1836
# Federal-gov           960
# Local-gov            2093
# Never-worked            7
# Private             22696
# Self-emp-inc         1116
# Self-emp-not-inc     2541
# State-gov            1298
# Without-pay            14
# dtype: int64

# %%
count_emp.plot(kind='barh')

# %% [markdown]
# In further analysis and model building, we may not want to include levels/values of categorical vairbales whose bars are too short. We may want to combine them into a single categroy
